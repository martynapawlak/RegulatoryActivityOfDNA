# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/martynapawlak/RegulatoryActivityOfDNA.git
# Out:
# fatal: destination path 'RegulatoryActivityOfDNA' already exists and is not an empty directory.

# %%
import sys
sys.path.append('/content/RegulatoryActivityOfDNA')

# %%
# !cd /content/RegulatoryActivityOfDNA && git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 363 bytes | 363.00 KiB/s, done.
# From https://github.com/martynapawlak/RegulatoryActivityOfDNA
#    2f2ee12..a884d97  main       -> origin/main
# Updating 2f2ee12..a884d97
# Fast-forward
#  training/train.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
from training.train import training_loop_CNN

# %%
train_path = "/content/drive/MyDrive/data/project1DL/train.tsv"
val_path = "/content/drive/MyDrive/data/project1DL/val.tsv"

# %%
model,train_losses, valid_losses = training_loop_CNN(train_path=train_path, val_path=val_path, epochs=100)
# Out:
# best new model saved !! :)
# epoch: 1, train loss: 0.7296, val loss: 0.7221, val acc: 67.4, val_r2: 0.0441
# BCE (class): 0.6461, MSE (reg): 0.9713
# best new model saved !! :)
# epoch: 2, train loss: 0.7210, val loss: 0.7217, val acc: 67.9, val_r2: 0.0471
# BCE (class): 0.6461, MSE (reg): 0.9679
# best new model saved !! :)
# epoch: 3, train loss: 0.7188, val loss: 0.7193, val acc: 67.9, val_r2: 0.0496
# BCE (class): 0.6479, MSE (reg): 0.9707
# best new model saved !! :)
# epoch: 4, train loss: 0.7177, val loss: 0.7178, val acc: 68.2, val_r2: 0.0526
# BCE (class): 0.6504, MSE (reg): 0.9848
# epoch: 5, train loss: 0.7164, val loss: 0.7180, val acc: 67.8, val_r2: 0.0524
# BCE (class): 0.6502, MSE (reg): 0.9678
# best new model saved !! :)
# epoch: 6, train loss: 0.7153, val loss: 0.7157, val acc: 68.2, val_r2: 0.0556
# BCE (class): 0.6504, MSE (reg): 0.9758
# best new model saved !! :)
# epoch: 7, train loss: 0.7152, val loss: 0.7145, val acc: 68.2, val_r2: 0.0575
# ...

# %%
import matplotlib.pyplot as plt
# simple plot
plt.plot(train_losses, label='train')
plt.plot(valid_losses, label='validation')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and validation loss")
plt.legend()
